# %% [markdown]
# # 03 — Fairness, stability, and limitations
#
# Interpret results as evidence about this dataset and protocol only; never as a compliance finding.

# %%
from stresstest_fin.evaluate import group_audit, explanation_stability_proxy
# Fit one selected baseline after reviewing Notebook 02.
# Only run group audits when the field is lawful, documented, and meaningful.

# %% [markdown]
# ## Required write-up
# - Dataset provenance and limitations
# - Exact train/test split and leakage checks
# - Metrics and confidence intervals
# - Failure cases and subgroup caveats
# - Reproducibility commands
# - Explicit non-deployment statement
